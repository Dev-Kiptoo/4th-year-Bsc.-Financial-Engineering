# %%
import yfinance as yf
prices = yf.download(tickers="TSLA", start='2010-12-01', end="2023-12-01")[['Adj Close']].copy()
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
print(prices)
# Out:
#              Adj Close
# Date
# 2010-12-01    2.290000
# 2010-12-02    2.156667
# 2010-12-03    2.099333
# 2010-12-06    2.020667
# 2010-12-07    2.104000
# ...                ...
# 2023-11-24  235.449997
# 2023-11-27  236.080002
# 2023-11-28  246.720001
# 2023-11-29  244.139999
# 2023-11-30  240.080002
#
# [3272 rows x 1 columns]

# %%
len(prices)
# Out:
# 3272

# %%
# prices log returns
import numpy as np
prices['Log Rets'] = np.log(prices['Adj Close'] / prices['Adj Close'].shift(1))
prices
# Out:
#              Adj Close  Log Rets
# Date
# 2010-12-01    2.290000       NaN
# 2010-12-02    2.156667 -0.059988
# 2010-12-03    2.099333 -0.026944
# 2010-12-06    2.020667 -0.038192
# 2010-12-07    2.104000  0.040413
# ...                ...       ...
# 2023-11-24  235.449997  0.005280
# 2023-11-27  236.080002  0.002672
# 2023-11-28  246.720001  0.044083
# 2023-11-29  244.139999 -0.010512
# 2023-11-30  240.080002 -0.016770
#
# [3272 rows x 2 columns]

# %%
# Daily and annual volatility
daily_vol = np.std(prices['Log Rets'])

# Annual volatility
Anual_vol =  daily_vol * 252 ** 0.5# 252 is the no of trading days

# %%
daily_vol
Anual_vol
# Out:
# 0.5629651477208599

# %%
import matplotlib.pyplot as plt
# plt.plot(prices['Adj Close'])
plt.plot(prices['Log Rets'])

plt.xlabel('Date')
plt.ylabel('Log returns')
plt.title('Open and Close Prices Over Time')
plt.legend()

plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
prices.head(10)
# Out:
#             Adj Close  Log Rets
# Date
# 2010-12-01   2.290000       NaN
# 2010-12-02   2.156667 -0.059988
# 2010-12-03   2.099333 -0.026944
# 2010-12-06   2.020667 -0.038192
# 2010-12-07   2.104000  0.040413
# 2010-12-08   2.158000  0.025342
# 2010-12-09   2.136667 -0.009935
# 2010-12-10   2.101333 -0.016675
# 2010-12-13   2.036667 -0.031257
# 2010-12-14   1.902000 -0.068409

# %%
plt.plot(prices['Adj Close'], prices['Log Rets'])
